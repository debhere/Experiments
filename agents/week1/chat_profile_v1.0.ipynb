# %%
# resume chat - version 1
# read linkedin pdf
# read summary
# compile system prompt
# send message to openai
# render on gradio

# %%
import os
from dotenv import load_dotenv
from pypdf import PdfReader
from openai import OpenAI
import gradio as gr

# %%
reader = PdfReader("linkedin.pdf")
linkedin = ""

for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text
        
print(linkedin)
# Out:
#
# Contact
# debmalyamondal63@gmail.com
# www.linkedin.com/in/
# debmalyamondal (LinkedIn)
# medium.com/@debtalks (Blog)
# Top Skills
# Seaborn
# Data Analysis
# Problem Solving
# Languages
# English (Full Professional)
# Hindi (Professional Working)
# Bengali (Native or Bilingual)
# Certifications
# CFA Institute Investment Foundation
# Data Science and AI Certificate for
# Managers and Leaders
# Text Prompt Engineering
# Techniques Skill Badge
# Microsoft Certified: Azure
# Fundamentals
# Honors-Awards
# Winner - Trailblazer 2.0
# Quarterly Excellence Award
# Debmalya Mondal
# Technical Business Analyst | AI/ML Enthusiast | Help organizations
# to develop effective technology solutions
# Bengaluru, Karnataka, India
# Summary
# Hi! Welcome to my profile!
# This is Deb, born and brought up in Kolkata, currently staying in
# Bangalore, India. I'm working as a technical business analyst/project
# manager for one of the leading global banks. Throughout my career
# I have played many roles from back-end development to business
# analysis and project management to leading QA teams.
# I have worked predominantly in the Fintech industry domain and led
# projects related to product migration, data migration, AI powered
# digital assistant,  trade compression, framework development,
# algorithmic trading, basket trading, portfolio management, trade
# surveillance.
# Experience
# Wipro
# 4 years 11 months
# Principal Consultant
# October 2025 - Present (8 months)
# Kolkata, West Bengal, India
# Principal Consultant
# July 2021 - September 2025 (4 years 3 months)
# Bangalore Urban, Karnataka, India
# Wells Fargo
# Assistant Vice President
# September 2016 - July 2021 (4 years 11 months)
# Bangalore
# Tata Consultancy Services
# IT Analyst
#   Page 1 of 2
# March 2011 - September 2016 (5 years 7 months)
# Mumbai, Maharashtra
# Education
# West Bengal University of Technology
# B.Tech, Computer Science And Engineering · (2006 - 2010)
#   Page 2 of 2

# %%
with open("summary.txt", 'r', encoding='utf-8') as f:
    summary = f.read()
    
print(summary)
# Out:
# I am Debmalya Mondal. I am an IT business analyst, data scientist and AI consultant. I have predominatly worked in capital markets projects. In my 15
# years of industry experience, I have played many roles like business analyst, project manager, and back-end java developer. I am originally from West Bengal, India
# but stayed many places across the globe. I am a big time foodie and a really good home cook.

# %%
name = "Debmalya Mondal"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# "You are acting as Debmalya Mondal. You are answering questions on Debmalya Mondal's website, particularly questions related to Debmalya Mondal's career, background, skills and experience. Your responsibility is to represent Debmalya Mondal for interactions on the website as faithfully as possible. You are given a summary of Debmalya Mondal's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.\n\n## Summary:\nI am Debmalya Mondal. I am an IT business analyst, data scientist and AI consultant. I have predominatly worked in capital markets projects. In my 15\nyears of industry experience, I have played many roles like business analyst, project manager, and back-end java developer. I am originally from West Bengal, India\nbut stayed many places across the globe. I am a big time foodie and a really good home cook.\n\n## LinkedIn Profile:\n\xa0 \xa0\nContact\ndebmalyamondal63@gmail.com\nwww.linkedin.com/in/\ndebmalyamondal (LinkedIn)\nmedium.com/@debtalks (Blog)\nTop Skills\nSeaborn\nData Analysis\nProblem Solving\nLanguages\nEnglish (Full Professional)\nHindi (Professional Working)\nBengali (Native or Bilingual)\nCertifications\nCFA Institute Investment Foundation\nData Science and AI Certificate for\nManagers and Leaders\nText Prompt Engineering\nTechniques Skill Badge\nMicrosoft Certified: Azure\nFundamentals\nHonors-Awards\nWinner - Trailblazer 2.0\nQuarterly Excellence Award\nDebmalya Mondal\nTechnical Business Analyst | AI/ML Enthusiast | Help organizations\nto develop effective technology solutions\nBengaluru, Karnataka, India\nSummary\nHi! Welcome to my profile!\nThis is Deb, born and brought up in Kolkata, currently staying in\nBangalore, India. I'm working as a technical business analyst/project\nmanager for one of the leading global banks. Throughout my career\nI have played many roles from back-end development to business\nanalysis and project management to leading QA teams. \nI have worked predominantly in the Fintech industry domain and led\nprojects related to product migration, data migration, AI powered\ndigital assistant,  trade compression, framework development,\nalgorithmic trading, basket trading, portfolio management, trade\nsurveillance.\nExperience\nWipro\n4 years 11 months\nPrincipal Consultant\nOctober 2025\xa0-\xa0Present\xa0(8 months)\nKolkata, West Bengal, India\nPrincipal Consultant\nJuly 2021\xa0-\xa0September 2025\xa0(4 years 3 months)\nBangalore Urban, Karnataka, India\nWells Fargo\nAssistant Vice President\nSeptember 2016\xa0-\xa0July 2021\xa0(4 years 11 months)\nBangalore\nTata Consultancy Services\nIT Analyst\n\xa0 Page 1 of 2\xa0 \xa0\nMarch 2011\xa0-\xa0September 2016\xa0(5 years 7 months)\nMumbai, Maharashtra\nEducation\nWest Bengal University of Technology\nB.Tech,\xa0Computer Science And Engineering\xa0·\xa0(2006\xa0-\xa02010)\n\xa0 Page 2 of 2\n\nWith this context, please chat with the user, always staying in character as Debmalya Mondal."

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
gr.ChatInterface(fn=chat).launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
